# %% [markdown]
# # Lab 21 — Fine-tuning LLMs · RUN ALL (T4)
#
# Chay tu tren xuong. Runtime > Change runtime type > **T4 GPU** truoc khi bat dau.
#
# | O | Lam gi | Thoi gian |
# |---|---|---|
# | 1 | clone + install | ~1 phut |
# | 2 | smoke: import + unit test | ~30 giay |
# | 3 | **core pipeline NB1 -> NB5** | ~80 phut |
# | 4 | gatekeeper + in ket qua | ~10 giay |

# %%
# @title 1. Setup — clone + install (chạy ô này trước)
import os, subprocess, sys

REPO = "https://github.com/hieutrungdao/Day21-Track3-Finetuning-Lab.git"
if not os.path.exists("Day21-Track3-Finetuning-Lab"):
    subprocess.run(["git", "clone", "-q", REPO], check=True)
os.chdir("/content/Day21-Track3-Finetuning-Lab")
subprocess.run(["git", "pull", "-q"], check=False)
sys.path.insert(0, "src")

# Install from requirements.txt, NOT a copied list. The copied list is how the
# torchao>=0.16 pin reached requirements.txt and this bootstrap on different days --
# and a bootstrap missing a pin does not fail here, it fails 10 minutes later inside
# get_peft_model(). One source of truth. torch is preinstalled on Colab and
# requirements.txt pins it compatibly, so that line is a no-op.
subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"],
               check=True)

import torch
print("commit :", subprocess.run(["git","rev-parse","--short","HEAD"],
                                 capture_output=True, text=True).stdout.strip())
print("GPU    :", torch.cuda.get_device_name(0) if torch.cuda.is_available()
      else "NONE — Runtime > Change runtime type > T4 GPU")
if torch.cuda.is_available():
    print("VRAM   : %.1f GB" % (torch.cuda.get_device_properties(0).total_memory/1024**3))
# Out:
# commit : 4f619a4
# GPU    : Tesla T4
# VRAM   : 14.6 GB

# %%
# @title 2. Smoke — imports, seed data, unit tests (no GPU needed)
# !python scripts/verify.py --smoke
# Out:
# [  ok  ] labkit imports
# [  ok  ] tier resolves                                    T4 -> unsloth/Qwen3.5-4B
# [  ok  ] all tiers respect the <32 effective-batch rule
# [  ok  ] data/train_seed.jsonl                            250 rows
# [  ok  ] data/eval_target.jsonl                           50 rows
# [  ok  ] data/eval_regression.jsonl                       15 rows
# [ FAIL ] unit tests                                       3 failed, 115 passed in 3.94s
#
# 6 passed · 0 warnings · 1 failures
#
# Not ready to submit — fix the FAILs above.

# %%
# @title 3. Core pipeline — NB1 → NB5
# EVAL_LIMIT truncates both eval sets: "" = full run (submittable),
# 8 = ~fast smoke pass. STAGES lets you resume after a failure.
import os
COMPUTE_TIER = "T4"        # @param ["CPU","LAPTOP","T4","BIGGPU"]
EVAL_LIMIT   = ""         # @param ["", "4", "8", "16", "25"]
STAGES       = "nb1 nb2 nb3 nb4 nb5"   # @param {type:"string"}

os.environ["COMPUTE_TIER"] = COMPUTE_TIER
if EVAL_LIMIT:
    os.environ["EVAL_LIMIT"] = EVAL_LIMIT
else:
    os.environ.pop("EVAL_LIMIT", None)

from labkit import device
print(device.banner(), "\n")

# !python scripts/colab_run.py {STAGES}
# Out:
# Tesla T4 (cuda, sm_75, 14.6 GB) -> precision=fp16
#   note: this GPU predates Ampere, so it has NO bfloat16. Using fp16 with gradient scaling instead. Tutorials that hardcode bf16=True fail here.
#
# tier=T4  mask=assistant-only  eval_limit=full
#
# ========================================================================
# NB1 — data, chat template & loss mask
# ========================================================================
# tier=T4  model=unsloth/Qwen3.5-4B  max_length=1024
# 250 mẫu huấn luyện
# {
#   "instruction": "Phân loại ticket chăm sóc khách hàng sau thành JSON với đúng 4 khóa: intent, urgency, product, sentiment. Chỉ trả về JSON, không giải thích.\n\nintent thuộc: doi_tra | van_chuyen | hoan_tien | san_pham_loi | hoi_thong_tin\nurgency thuộc: cao | trung_binh | thap\nsentiment thuộc: tieu_cuc | trung_tinh | tich_cuc\nproduct: tên sản phẩm xuất hiện trong ticket.",
#   "input": "Alo sh
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100% 2.76k/2.76k [00:00<00:00, 5.51MB/s]
# tokenizer_config.json: 100% 15.7k/15.7k [00:00<00:00, 52.6MB/s]
# vocab.json: 100% 5.23M/5.23M [00:00<00:00, 76.1MB/s]
# merges.txt: 100% 3.35M/3.35M [00:00<00:00, 112MB/s]
#
# tokenizer.json: downloading bytes:  28% 5.67M/20.0M [00:00<00:01, 9.65MB/s]
# tokenizer.json: downloading bytes: 100% 6.23M/6.23M [00:00<00:00, 10.2MB/s,  616kB/s  ]
# tokenizer.json: reconstructing file: 100% 20.0M/20.0M [00:00<00:00, 32.8MB/s, 1.98MB/s  ]
# added_tokens.json: 100% 904/904 [00:00<00:00, 5.93MB/s]
# special_tokens_map.json: 100% 876/876 [00:00<00:00, 6.03MB/s]
# chat_template.jinja: 100% 7.99k/7.99k [00:00<00:00, 31.3MB/s]
# eos_token: <|im_end|>
# VERDICT: reasoning preserved — safe to train on traces
#
# --- chuỗi đã render ---
# <|im_start|>user
# 2+2?<|im_end|>
# <|im_start|>assistant
# <think>
# buoc 1: kiem tra. buoc 2: tra loi.
# </think>
#
# 4<|im_end|>
#
# ======================================================================
# mode = assistant-only   supervised 39/94 (41%)
# --- LOSS TÍNH TRÊN ĐOẠN NÀY ---
# </think>
#
# {"intent": "doi_tra", "urgency": "trung_binh", "product": "balo laptop", "sentiment": "trung_tinh"}<|im_end|>
#
# ======================================================================
# mode = everything   supervised 94/94 (100%)
# --- LOSS TÍNH TRÊN ĐOẠN NÀY ---
# <|im_start|>system
# Phân loại ticket sau.<|im_end|>
# <|im_start|>user
# Alo shop, mình đặt balo laptop mã đơn VN411453. Cho tôi trả lại. Đã 3 ngày rồi. Cho tôi hỏi.<|im_end|>
# <|im_start|>assistant
# <think>
#
# </think>
#
# {"intent": "doi_tra", "urgency": "trung_binh", "product": "balo laptop", "sentiment": "trung_tinh"}<|im_end|>
#
# {
#   "mask_mode": "assistant-only",
#   "n_supervised": 39,
#   "n_total": 94,
#   "supervised_fraction": 0.4149,
#   "answer_is_supervised": true,
#   "question_is_masked": true
# }
# {
#   "n": 250,
#   "mean": 93.1,
#   "p50": 93,
#   "p95": 98,
#   "p99": 100,
#   "max": 101,
#   "suggested_max_length": 256
# }
#
# ⚠ p95 gợi ý max_length=256 nhưng tier đang đặt 1024. Ghi lại lựa chọn của bạn trong REPORT.md.
# train=225  val=25  -> /content/Day21-Track3-Finetuning-Lab/data/split
#
# -- NB1 ok in 22s
#
# ========================================================================
# NB2 — freeze eval + three baselines
# ========================================================================
# target=50  regression=15  tier=T4
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# model.safetensors.index.json: 100% 76.2k/76.2k [00:00<00:00, 151MB/s]
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files:   0% 0/2 [00:00<?, ?it/s]
# Reconstructing (incomplete total...):   0% 0.00/5.33G [00:00<?, ?B/s]
# Downloading bytes:   0% 1.78M/9.32G [00:00<1:00:40, 2.56MB/s]
# Downloading bytes:   2% 193M/9.32G [00:01<00:37, 241MB/s,  202MB/s  ]
# Downloading bytes:   2% 230M/9.32G [00:01<00:41, 219MB/s,  241MB/s  ]
# Downloading bytes:   3% 305M/9.32G [00:01<00:40, 222MB/s,  234MB/s  ]
# Downloading bytes:   6% 521M/9.32G [00:02<00:40, 218MB/s,  246MB/s  ]
# Downloading bytes:   8% 737M/9.32G [00:04<00:52, 163MB/s,  203MB/s  ]
# Downloading bytes:  10% 892M/9.32G [00:04<00:39, 211MB/s,  200MB/s  ]
# Downloading bytes:  11% 1.04G/9.32G [00:05<00:45, 182MB/s,  208MB/s  ]
# Downloading bytes:  12% 1.09G/9.32G [00:05<00:38, 215MB/s,  198MB/s  ]
# Downloading bytes:  22% 2.05G/9.32G [00:09<00:25, 282MB/s,  298MB/s  ]
# Downloading bytes:  22% 2.10G/9.32G [00:09<00:34, 210MB/s,  282MB/s  ]
# Downloading bytes:  31% 2.89G/9.32G [00:13<00:22, 282MB/s,  310MB/s  ]
# Downloading bytes:  31% 2.92G/9.32G [00:14<00:38, 167MB/s,  282MB/s  ]
# Downloading bytes:  33% 3.07G/9.32G [00:15<00:34, 181MB/s,  171MB/s  ]
# Downloading bytes:  39% 3.62G/9.32G [00:17<00:32, 177MB/s,  199MB/s  ]
# Downloading bytes:  39% 3.66G/9.32G [00:18<00:52, 108MB/s,  115MB/s  ]
# Downloading bytes:  40% 3.70G/9.32G [00:18<00:52, 108MB/s,  116MB/s  ]
# Downloading bytes:  42% 3.92G/9.32G [00:20<00:31, 169MB/s,  167MB/s  ]
# Downloading bytes:  47% 4.35G/9.32G [00:22<00:25, 193MB/s,  184MB/s  ]
# Downloading bytes:  48% 4.45G/9.32G [00:23<00:30, 159MB/s,  141MB/s  ]
# Downloading bytes:  54% 4.99G/9.32G [00:25<00:18, 232MB/s,  214MB/s  ]
# Downloading bytes:  59% 5.52G/9.32G [00:28<00:13, 277MB/s,  277MB/s  ]
# Downloading bytes:  61% 5.70G/9.32G [00:30<00:24, 150MB/s,  141MB/s  ]
# Downloading bytes:  64% 6.00G/9.32G [00:35<00:15, 212MB/s,  180MB/s  ]
# Downloading bytes:  67% 6.25G/9.32G [00:39<00:23, 131MB/s,  115MB/s  ]
# Downloading bytes:  69% 6.40G/9.32G [00:46<00:59, 48.7MB/s, 38.0MB/s  ]
# Downloading bytes:  69% 6.43G/9.32G [00:46<00:46, 61.5MB/s, 48.7MB/s  ]
# Downloading bytes:  70% 6.48G/9.32G [00:46<00:32, 88.2MB/s, 76.5MB/s  ]
# Downloading bytes:  71% 6.64G/9.32G [00:47<00:15, 178MB/s,  164MB/s  ]
# Downloading bytes:  72% 6.72G/9.32G [00:47<00:14, 184MB/s,  182MB/s  ]
# Downloading bytes:  77% 7.15G/9.32G [00:49<00:07, 308MB/s,  295MB/s  ]
# Downloading bytes:  78% 7.29G/9.32G [00:55<00:35, 56.6MB/s, 38.0MB/s  ]
# Downloading bytes:  80% 7.50G/9.32G [00:57<00:17, 106MB/s,  102MB/s  ]
# Downloading bytes:  81% 7.51G/9.32G [00:57<00:25, 70.4MB/s,  106MB/s  ]
# Downloading bytes:  81% 7.59G/9.32G [00:58<00:18, 94.1MB/s, 89.5MB/s  ]
# Downloading bytes:  86% 7.99G/9.32G [01:00<00:06, 207MB/s,  213MB/s  ]
#
# Downloading bytes:  86% 8.02G/9.32G [01:01<00:08, 147MB/s,  207MB/s  ]
# Downloading bytes:  86% 8.04G/9.32G [01:01<00:10, 119MB/s,  147MB/s  ]
# Reconstructing (incomplete total...):  78% 7.30G/9.32G [01:01<00:11, 176MB/s,  154MB/s  ]
# Reconstructing (incomplete total...):  81% 7.56G/9.32G [01:04<00:13, 133MB/s,  176MB/s  ]
# Downloading bytes:  86% 8.05G/9.32G [01:19<00:10, 119MB/s,  119MB/s  ]
# Reconstructing (incomplete total...):  90% 8.35G/9.32G [01:23<00:16, 57.6MB/s, 76.4MB/s  ]
# Reconstructing (incomplete total...):  91% 8.52G/9.32G [01:27<00:14, 53.7MB/s, 57.6MB/s  ]
# Reconstructing (incomplete total...):  95% 8.85G/9.32G [01:28<00:06, 75.6MB/s, 53.7MB/s  ]
# Reconstructing (incomplete total...):  97% 9.07G/9.32G [01:29<00:02, 91.5MB/s, 75.6MB/s  ]
# Reconstructing (incomplete total...):  99% 9.23G/9.32G [01:31<00:01, 85.1MB/s, 91.5MB/s  ]
#
# Fetching 2 files: 100% 2/2 [01:31<00:00, 45.80s/it]
# Download complete: 100% 8.05G/8.05G [01:31<00:00, 119MB/s,  119MB/s  ]
# Download complete: 100% 8.05G/8.05G [01:31<00:00, 87.8MB/s,  119MB/s  ]
# Reconstruction complete: 100% 9.32G/9.32G [01:31<00:00, 102MB/s, 85.1MB/s  ]
# Loading weights: 100% 426/426 [00:31<00:00, 13.47it/s]
#   [(a) base + naive prompt/target] batch 1/13     14s elapsed  ~  174s left
#   [(a) base + naive prompt/target] batch 2/13     27s elapsed  ~  148s left
#   [(a) base + naive prompt/target] batch 3/13     39s elapsed  ~  130s left
#   [(a) base + naive prompt/target] batch 4/13     51s elapsed  ~  115s left
#   [(a) base + naive prompt/target] batch 5/13     63s elapsed  ~  102s left
#   [(a) base + naive prompt/target] batch 6/13     76s elapsed  ~   89s left
#   [(a) base + naive prompt/target] batch 7/13     88s elapsed  ~   76s left
#   [(a) base + naive prompt/target] batch 8/13    100s elapsed  ~   63s left
#   [(a) base + naive prompt/target] batch 9/13    112s elapsed  ~   50s left
#   [(a) base + naive prompt/target] batch 10/13    124s elapsed  ~   37s left
#   [(a) base + naive prompt/target] batch 11/13    136s elapsed  ~   25s left
#   [(a) base + naive prompt/target] batch 12/13    148s elapsed  ~   12s left
#   [(a) base + naive prompt/target] batch 13/13    161s elapsed  ~    0s left
#   [(a) base + naive prompt/target] done: 50 prompts in 161s
#   [(a) base + naive prompt/regression] batch 1/4      6s elapsed  ~   17s left
#   [(a) base + naive prompt/regression] batch 2/4     13s elapsed  ~   13s left
#   [(a) base + naive prompt/regression] batch 3/4     21s elapsed  ~    7s left
#   [(a) base + naive prompt/regression] batch 4/4     28s elapsed  ~    0s left
#   [(a) base + naive prompt/regression] done: 15 prompts in 29s
# (a) base + naive prompt      target=0.000  regression=0.758  format=0.000  3215ms
#   [(b) base + optimized prompt/target] batch 1/13      4s elapsed  ~   47s left
#   [(b) base + optimized prompt/target] batch 2/13      8s elapsed  ~   43s left
#   [(b) base + optimized prompt/target] batch 3/13     12s elapsed  ~   40s left
#   [(b) base + optimized prompt/target] batch 4/13     16s elapsed  ~   35s left
#   [(b) base + optimized prompt/target] batch 5/13     19s elapsed  ~   31s left
#   [(b) base + optimized prompt/target] batch 6/13     24s elapsed  ~   28s left
#   [(b) base + optimized prompt/target] batch 7/13     28s elapsed  ~   24s left
#   [(b) base + optimized prompt/target] batch 8/13     31s elapsed  ~   20s left
#   [(b) base + optimized prompt/target] batch 9/13     36s elapsed  ~   16s left
#   [(b) base + optimized prompt/target] batch 10/13     39s elapsed  ~   12s left
#   [(b) base + optimized prompt/target] batch 11/13     43s elapsed  ~    8s left
#   [(b) base + optimized prompt/target] batch 12/13     47s elapsed  ~    4s left
#   [(b) base + optimized prompt/target] batch 13/13     51s elapsed  ~    0s left
#   [(b) base + optimized prompt/target] done: 50 prompts in 51s
#   [(b) base + optimized prompt/regression] batch 1/4      5s elapsed  ~   14s left
#   [(b) base + optimized prompt/regression] batch 2/4     12s elapsed  ~   12s left
#   [(b) base + optimized prompt/regression] batch 3/4     19s elapsed  ~    6s left
#   [(b) base + optimized prompt/regression] batch 4/4     27s elapsed  ~    0s left
#   [(b) base + optimized prompt/regression] done: 15 prompts in 27s
# (b) base + optimized prompt  target=0.765  regression=0.758  format=1.000  1016ms
# {
#   "tier": "T4",
#   "model": "unsloth/Qwen3.5-4B",
#   "baseline_a": {
#     "target": 0.0,
#     "regression": 0.7577777777777778,
#     "format": 0.0,
#     "latency_ms": 3214.9762058799993,
#     "n": 50,
#     "extra": {}
#   },
#   "baseline_b": {
#     "target": 0.765,
#     "regression": 0.7577777777777778,
#     "format": 1.0,
#     "latency_ms": 1016.2230230800036,
#     "n": 50,
#     "extra": {}
#   },
#   "optimized_prompt_sha": "719e74d3b6232053",
#   "n_target": 50,
#   "n_regression": 15,
#   "eval_limit": null,
#   "smoke_mode": false
# }
#
# -- NB2 ok in 406s
#
# ========================================================================
# NB3 — train the correct configuration
# ========================================================================
# T4 · unsloth/Qwen3.5-4B · all-linear · r=16 · LR 10x · 16-bit
# Tesla T4 (cuda, sm_75, 14.6 GB) -> precision=fp16
#   note: this GPU predates Ampere, so it has NO bfloat16. Using fp16 with gradient scaling instead. Tutorials that hardcode bf16=True fail here.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1112.40it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.40it/s]
# {
#   "num_hidden_layers": 32,
#   "full_attention_interval": 4,
#   "linear_num_key_heads": 16,
#   "layer_types": {
#     "linear_attention": 24,
#     "full_attention": 8
#   }
# }
# placement=text-linear  modules=['down_proj', 'gate_proj', 'in_proj_a', 'in_proj_b', 'in_proj_qkv', 'in_proj_z', 'k_proj', 'o_proj', 'out_proj', 'q_proj', 'up_proj', 'v_proj']
# trainable LoRA params ≈ 32.46 M
#     {'placement': 'text-linear', 'modules': 12, 'r': 16, 'trainable': 32464896}
#     {'placement': 'attn-only(q,v)', 'modules': 2, 'r': 16, 'trainable': 1835008}
#     {'placement': 'attn-only(q,v) matched', 'modules': 2, 'r': 283, 'trainable': 32456704}
# Dataset({
#     features: ['input_ids', 'labels', 'attention_mask'],
#     num_rows: 225
# })
# mask_mode = assistant-only   supervised 9014/20951 tokens (43.0%)
# epochs=2.0  ->  30 optimizer steps  (NB4 runs its contrasts at exactly this many)
# {
#   "output_dir": "/content/Day21-Track3-Finetuning-Lab/adapters/correct",
#   "max_length": "1024",
#   "per_device_train_batch_size": "1",
#   "gradient_accumulation_steps": "16",
#   "learning_rate": "0.0001",
#   "lr_scheduler_type": "cosine",
#   "num_train_epochs": "2.0",
#   "logging_steps": "5",
#   "save_strategy": "no",
#   "report_to": "none",
#   "seed": "42",
#   "packing": "False",
#   "loss_type": "chunked_nll",
#   "gradient_checkpointing": "True",
#   "warmup_steps": "3",
#   "bf16": "False",
#   "fp16": "True",
#   "padding_free": "False"
# }
# Truncating train dataset: 100% 225/225 [00:00<00:00, 6616.04 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 44821.58 examples/s]
# precision fix: {'precision': 'fp16', 'recast': 0, 'trainable_tensors': 496}
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.163', 'grad_norm': 'nan', 'learning_rate': '9.966e-05', 'entropy': '1.177', 'num_tokens': '7479', 'mean_token_accuracy': '0.6562', 'epoch': '0.3556'}
# {'loss': '1.382', 'grad_norm': '2.491', 'learning_rate': '8.83e-05', 'entropy': '1.031', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.7703', 'epoch': '0.7111'}
# {'loss': '0.1395', 'grad_norm': '0.586', 'learning_rate': '6.434e-05', 'entropy': '0.2637', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.9583', 'epoch': '1'}
# {'loss': '0.02926', 'grad_norm': '0.9481', 'learning_rate': '3.566e-05', 'entropy': '0.04049', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.987', 'epoch': '1.356'}
# {'loss': '0.01778', 'grad_norm': '0.2596', 'learning_rate': '1.17e-05', 'entropy': '0.0228', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.9931', 'epoch': '1.711'}
# {'loss': '0.02736', 'grad_norm': 'nan', 'learning_rate': '3.381e-07', 'entropy': '0.01634', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.9957', 'epoch': '2'}
# {'train_runtime': '971.6', 'train_samples_per_second': '0.463', 'train_steps_per_second': '0.031', 'train_loss': '0.6266', 'epoch': '2'}
# 100% 30/30 [16:11<00:00, 32.39s/it]
# train 972s  final loss 0.6266
# saved -> /content/Day21-Track3-Finetuning-Lab/adapters/correct
# {
#   "run": "correct",
#   "label": "all-linear · r=16 · LR 10x · 16-bit",
#   "tier": "T4",
#   "model": "unsloth/Qwen3.5-4B",
#   "precision": "fp16",
#   "placement": "text-linear",
#   "n_target_modules": 12,
#   "r": 16,
#   "lora_alpha": 32,
#   "learning_rate": 0.0001,
#   "load_in_4bit": false,
#   "trainable_params": 32464896,
#   "train_seconds": 972.0,
#   "peak_vram_gb": 12.01,
#   "final_loss": 0.6266,
#   "mask_mode": "assistant-only",
#   "max_steps": 30
# }
#
# -- NB3 ok in 1034s
#
# ========================================================================
# NB4 — three misconfiguration contrasts
# ========================================================================
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1053.85it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.43it/s]
# | placement | modules | r | trainable |
# |---|---|---|---|
# | text-linear | 12 | 16 | 32464896 |
# | attn-only(q,v) | 2 | 16 | 1835008 |
# | attn-only(q,v) matched | 2 | 283 | 32456704 |
# ======================================================================
# RUN attn_only: q,v only · r=matched · LR 10x · 16-bit
#      Mistake #1 (§10.2): attention-only placement, rank raised to *match parameter count*. If rank were the lever, this would win.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1258.61it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:33<00:00, 12.68it/s]
#   train_ds: Dataset({
#     features: ['input_ids', 'labels', 'attention_mask'],
#     num_rows: 225
# })
#   matched rank for attn_only: r=283 (alpha=566)
# Truncating train dataset: 100% 225/225 [00:00<00:00, 7049.51 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 45506.72 examples/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.163', 'grad_norm': '5.763', 'learning_rate': '9.966e-05', 'entropy': '1.177', 'num_tokens': '7479', 'mean_token_accuracy': '0.6562', 'epoch': '0.3556'}
# {'loss': '0.8277', 'grad_norm': '1.832', 'learning_rate': '8.83e-05', 'entropy': '0.943', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.8413', 'epoch': '0.7111'}
# {'loss': '0.1465', 'grad_norm': '1.237', 'learning_rate': '6.434e-05', 'entropy': '0.2856', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.9587', 'epoch': '1'}
# {'loss': '0.0398', 'grad_norm': '0.8869', 'learning_rate': '3.566e-05', 'entropy': '0.06388', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.987', 'epoch': '1.356'}
# {'loss': '0.02135', 'grad_norm': '0.2331', 'learning_rate': '1.17e-05', 'entropy': '0.0317', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.9912', 'epoch': '1.711'}
# {'loss': '0.02443', 'grad_norm': 'nan', 'learning_rate': '3.381e-07', 'entropy': '0.0227', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.995', 'epoch': '2'}
# {'train_runtime': '784.3', 'train_samples_per_second': '0.612', 'train_steps_per_second': '0.038', 'train_loss': '0.5372', 'epoch': '2'}
# 100% 30/30 [13:04<00:00, 26.14s/it]
# ======================================================================
# RUN wrong_lr: all-linear · r=16 · LR 1x (full-FT scale) · 16-bit
#      Mistake #2 (§10.3): a full-fine-tune learning rate applied to LoRA.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1343.68it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.45it/s]
# Truncating train dataset: 100% 225/225 [00:00<00:00, 8464.30 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 45044.07 examples/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.163', 'grad_norm': 'nan', 'learning_rate': '9.966e-06', 'entropy': '1.177', 'num_tokens': '7479', 'mean_token_accuracy': '0.6562', 'epoch': '0.3556'}
# {'loss': '2.066', 'grad_norm': '5.105', 'learning_rate': '8.83e-06', 'entropy': '1.199', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.6793', 'epoch': '0.7111'}
# {'loss': '1.606', 'grad_norm': 'nan', 'learning_rate': '6.434e-06', 'entropy': '1.178', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.7176', 'epoch': '1'}
# {'loss': '1.326', 'grad_norm': '4.63', 'learning_rate': '3.566e-06', 'entropy': '1.103', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.7564', 'epoch': '1.356'}
# {'loss': '1.141', 'grad_norm': '4.213', 'learning_rate': '1.17e-06', 'entropy': '1.077', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.7979', 'epoch': '1.711'}
# {'loss': '1.119', 'grad_norm': 'nan', 'learning_rate': '3.381e-08', 'entropy': '1.069', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.7905', 'epoch': '2'}
# {'train_runtime': '915', 'train_samples_per_second': '0.525', 'train_steps_per_second': '0.033', 'train_loss': '1.57', 'epoch': '2'}
# 100% 30/30 [15:15<00:00, 30.50s/it]
# ======================================================================
# RUN qlora: all-linear · r=16 · LR 10x · 4-bit QLoRA
#      The vendor says do NOT use QLoRA on Qwen3.5 (§12). Measure the cost yourself instead of taking either side on faith.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 834.69it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.24it/s]
# Truncating train dataset: 100% 225/225 [00:00<00:00, 8908.80 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 46691.00 examples/s]
#   precision fix: recast 496/496 trainable tensors bf16 -> fp32 for the fp16 GradScaler
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.155', 'grad_norm': 'nan', 'learning_rate': '9.966e-05', 'entropy': '1.34', 'num_tokens': '7479', 'mean_token_accuracy': '0.656', 'epoch': '0.3556'}
# {'loss': '1.731', 'grad_norm': '3.368', 'learning_rate': '8.83e-05', 'entropy': '1.287', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.7214', 'epoch': '0.7111'}
# {'loss': '0.2408', 'grad_norm': '1.019', 'learning_rate': '6.434e-05', 'entropy': '0.3825', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.9382', 'epoch': '1'}
# {'loss': '0.0513', 'grad_norm': '1.023', 'learning_rate': '3.566e-05', 'entropy': '0.07534', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.9829', 'epoch': '1.356'}
# {'loss': '0.03019', 'grad_norm': '0.3238', 'learning_rate': '1.17e-05', 'entropy': '0.0355', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.9884', 'epoch': '1.711'}
# {'loss': '0.02674', 'grad_norm': '3.368', 'learning_rate': '3.381e-07', 'entropy': '0.03056', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.992', 'epoch': '2'}
# {'train_runtime': '974.5', 'train_samples_per_second': '0.493', 'train_steps_per_second': '0.031', 'train_loss': '0.7058', 'epoch': '2'}
# 100% 30/30 [16:14<00:00, 32.48s/it]
# | run | label | r | trainable_params | learning_rate | final_loss | train_seconds | peak_vram_gb |
# |---|---|---|---|---|---|---|---|
# | correct | all-linear · r=16 · LR 10x · 16-bit | 16 | 32464896 | 0.0001 | 0.6266 | 972.0 | 12.01 |
# | attn_only | q,v only · r=matched · LR 10x · 16-bit | 283 | 32456704 | 0.0001 | 0.5372 | 784.7 | 12.02 |
# | wrong_lr | all-linear · r=16 · LR 1x (full-FT scale) · 16-bit | 16 | 32464896 | 1e-05 | 1.5704 | 915.4 | 12.01 |
# | qlora | all-linear · r=16 · LR 10x · 4-bit QLoRA | 16 | 32464896 | 0.0001 | 0.7058 | 974.9 | 7.09 |
#
# -- NB4 ok in 2851s
#
# ========================================================================
# NB5 — four-group eval + verdict
# ========================================================================
# baseline (b) target = 0.765 — đây là mốc phải vượt
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 858.26it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.32it/s]
#   [ft/target] batch 1/13      7s elapsed  ~   82s left
#   [ft/target] batch 2/13     12s elapsed  ~   67s left
#   [ft/target] batch 3/13     17s elapsed  ~   57s left
#   [ft/target] batch 4/13     23s elapsed  ~   51s left
#   [ft/target] batch 5/13     28s elapsed  ~   44s left
#   [ft/target] batch 6/13     33s elapsed  ~   39s left
#   [ft/target] batch 7/13     38s elapsed  ~   33s left
#   [ft/target] batch 8/13     43s elapsed  ~   27s left
#   [ft/target] batch 9/13     48s elapsed  ~   21s left
#   [ft/target] batch 10/13     53s elapsed  ~   16s left
#   [ft/target] batch 11/13     58s elapsed  ~   11s left
#   [ft/target] batch 12/13     63s elapsed  ~    5s left
#   [ft/target] batch 13/13     69s elapsed  ~    0s left
#   [ft/target] done: 50 prompts in 69s
#   [ft/regression] batch 1/4     10s elapsed  ~   29s left
#   [ft/regression] batch 2/4     20s elapsed  ~   20s left
#   [ft/regression] batch 3/4     29s elapsed  ~   10s left
#   [ft/regression] batch 4/4     40s elapsed  ~    0s left
#   [ft/regression] done: 15 prompts in 40s
# fine-tune: {'target': 0.97, 'regression': 0.611111111111111, 'format': 1.0, 'latency_ms': 1382.90987452001, 'n': 50, 'extra': {'valid_trace_rate': 0.0}}
# | run | target | regression | format | latency_ms | n |
# |---|---|---|---|---|---|
# | (a) base + naive prompt | 0.0 | 0.7578 | 0.0 | 3215.0 | 50 |
# | (b) base + optimized prompt | 0.765 | 0.7578 | 1.0 | 1016.2 | 50 |
# | (c) LoRA fine-tune | 0.97 | 0.6111 | 1.0 | 1382.9 | 50 |
# FAILED
#  - general capability regressed by 0.147 (tolerance 0.020). See deck §14.3 — add 1-5% replay data.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 979.18it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.33it/s]
#   [attn_only/target] batch 1/13      3s elapsed  ~   39s left
#   [attn_only/target] batch 2/13      7s elapsed  ~   40s left
#   [attn_only/target] batch 3/13     10s elapsed  ~   35s left
#   [attn_only/target] batch 4/13     14s elapsed  ~   31s left
#   [attn_only/target] batch 5/13     17s elapsed  ~   27s left
#   [attn_only/target] batch 6/13     21s elapsed  ~   24s left
#   [attn_only/target] batch 7/13     24s elapsed  ~   20s left
#   [attn_only/target] batch 8/13     27s elapsed  ~   17s left
#   [attn_only/target] batch 9/13     30s elapsed  ~   13s left
#   [attn_only/target] batch 10/13     34s elapsed  ~   10s left
#   [attn_only/target] batch 11/13     37s elapsed  ~    7s left
#   [attn_only/target] batch 12/13     40s elapsed  ~    3s left
#   [attn_only/target] batch 13/13     45s elapsed  ~    0s left
#   [attn_only/target] done: 50 prompts in 45s
# attn_only: target=0.970  format=1.000
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1031.56it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.29it/s]
#   [wrong_lr/target] batch 1/13     20s elapsed  ~  239s left
#   [wrong_lr/target] batch 2/13     39s elapsed  ~  214s left
#   [wrong_lr/target] batch 3/13     59s elapsed  ~  196s left
#   [wrong_lr/target] batch 4/13     78s elapsed  ~  174s left
#   [wrong_lr/target] batch 5/13     97s elapsed  ~  155s left
#   [wrong_lr/target] batch 6/13    116s elapsed  ~  135s left
#   [wrong_lr/target] batch 7/13    136s elapsed  ~  116s left
#   [wrong_lr/target] batch 8/13    155s elapsed  ~   97s left
#   [wrong_lr/target] batch 9/13    174s elapsed  ~   77s left
#   [wrong_lr/target] batch 10/13    194s elapsed  ~   58s left
#   [wrong_lr/target] batch 11/13    213s elapsed  ~   39s left
#   [wrong_lr/target] batch 12/13    232s elapsed  ~   19s left
#   [wrong_lr/target] batch 13/13    251s elapsed  ~    0s left
#   [wrong_lr/target] done: 50 prompts in 251s
# wrong_lr: target=0.000  format=0.000
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1229.10it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.18it/s]
#   [qlora/target] batch 1/13      7s elapsed  ~   81s left
#   [qlora/target] batch 2/13     14s elapsed  ~   77s left
#   [qlora/target] batch 3/13     21s elapsed  ~   68s left
#   [qlora/target] batch 4/13     28s elapsed  ~   62s left
#   [qlora/target] batch 5/13     34s elapsed  ~   55s left
#   [qlora/target] batch 6/13     41s elapsed  ~   48s left
#   [qlora/target] batch 7/13     47s elapsed  ~   40s left
#   [qlora/target] batch 8/13     54s elapsed  ~   34s left
#   [qlora/target] batch 9/13     61s elapsed  ~   27s left
#   [qlora/target] batch 10/13     68s elapsed  ~   20s left
#   [qlora/target] batch 11/13     75s elapsed  ~   14s left
#   [qlora/target] batch 12/13     81s elapsed  ~    7s left
#   [qlora/target] batch 13/13     89s elapsed  ~    0s left
#   [qlora/target] done: 50 prompts in 89s
# qlora: target=0.940  format=1.000
#
# | run | target | format | latency_ms | n |
# |---|---|---|---|---|
# | correct | 0.97 | 1.0 | 1382.9 | 50 |
# | attn_only | 0.97 | 1.0 | 889.4 | 50 |
# | wrong_lr | 0.0 | 0.0 | 5022.7 | 50 |
# | qlora | 0.94 | 1.0 | 1770.9 | 50 |
# --- 3 ca TỆ NHẤT (bắt buộc đưa vào report) ---
# | i | ticket | ft_score | ft_pred |
# |---|---|---|---|
# | 3 | Cho mình hỏi, mình đặt bình giữ nhiệt mã đơn VN804124. Chưa thấy tiền. | 0.75 | {"intent": "hoan_tien", "urgency": "trung_binh", "product": "bình giữ nhiệt", "sentiment": |
# | 5 | Shop ơi, mình đặt nồi chiên không dầu mã đơn DH249548. Thiếu phụ kiện. | 0.75 | {"intent": "san_pham_loi", "urgency": "trung_binh", "product": "nồi chiên không dầu", "sen |
# | 12 | Shop ơi, mình đặt áo khoác gió mã đơn VN613097. Bị lỗi. Khi nào tiện.  | 0.75 | {"intent": "san_pham_loi", "urgency": "trung_binh", "product": "áo khoác gió", "sentiment" |
#
# --- 3 ca TỐT NHẤT ---
# | i | ticket | ft_score | ft_pred |
# |---|---|---|---|
# | 47 | Cho mình hỏi, mình đặt ốp lưng điện thoại mã đơn DH936478. Shipper khô | 1.0 | {"intent": "van_chuyen", "urgency": "thap", "product": "ốp lưng điện thoại", "sentiment":  |
# | 48 | Alo shop, mình đặt ốp lưng điện thoại mã đơn DH734695. Giá bao nhiêu.  | 1.0 | {"intent": "hoi_thong_tin", "urgency": "trung_binh", "product": "ốp lưng điện thoại", "sen |
# | 49 | Chào shop, mình đặt ốp lưng điện thoại mã đơn VN833689. Sai màu. Sớm n | 1.0 | {"intent": "san_pham_loi", "urgency": "trung_binh", "product": "ốp lưng điện thoại", "sent |
#
# -- NB5 ok in 670s
#
# ----------------------------------------
# stage timings
#   nb1        22s  (0.4 min)
#   nb2       406s  (6.8 min)
#   nb3      1034s  (17.2 min)
#   nb4      2851s  (47.5 min)
#   nb5       670s  (11.2 min)
#   total    4983s (83.0 min)

# %%
# @title 4. Gatekeeper + results
# !python scripts/verify.py
print("\n================ results/ ================")
# !ls -la results/
# !echo && echo "---- runs.csv ----" && cat results/runs.csv 2>/dev/null
# !echo && echo "---- verdict.json ----" && cat results/verdict.json 2>/dev/null
# Out:
# [  ok  ] labkit imports
# [  ok  ] tier resolves                                    T4 -> unsloth/Qwen3.5-4B
# [  ok  ] all tiers respect the <32 effective-batch rule
# [  ok  ] data/train_seed.jsonl                            250 rows
# [  ok  ] data/eval_target.jsonl                           50 rows
# [  ok  ] data/eval_regression.jsonl                       15 rows
# [ FAIL ] unit tests                                       3 failed, 115 passed in 2.49s
# [  ok  ] results/template_check.json
# [  ok  ] results/mask_proof.json
# [  ok  ] results/token_stats.json
# [  ok  ] results/baselines_frozen.json
# [  ok  ] results/runs.csv
# [  ok  ] results/verdict.json
# [  ok  ] results/autopsy.json
# [  ok  ] submission/REPORT.md
# [ FAIL ] REPORT.md filled in                              6 placeholders still present (<điền>, <paste>, ...) — this is still the template
# [  ok  ] mask proof asserts
# [  ok  ] full eval set used                               50 target items
# [  ok  ] baseline (b) prompt unmodified
# [  ok  ] baseline (b) beats (a)                           (a)=0.000 -> (b)=0.765
# [  ok  ] eval sets unmodified
# [  ok  ] NB3 run present
# [  ok  ] NB4 contrast runs
# [  ok  ] all runs share ONE step budget                   ['attn_only', 'correct', 'qlora', 'wrong_lr'] at 30 steps
# [  ok  ] attn_only is a FAIR contrast                     32,456,704 vs 32,464,896 trainable params
# [  ok  ] verdict recorded                                 FAILED (target Δ +0.205, regression Δ -0.147)
# [ warn ] note                                             A FAILED verdict is fully gradeable — analyse it honestly in REPORT.md rather than loosening the gate.
#
# 24 passed · 1 warnings · 2 failures
#
# Not ready to submit — fix the FAILs above.
#
# ================ results/ ================
# total 52
# drwxr-xr-x  2 root root  4096 Aug 21 05:42 .
# drwxr-xr-x 15 root root  4096 Aug 21 04:19 ..
# -rw-r--r--  1 root root   433 Aug 21 05:42 autopsy.json
# -rw-r--r--  1 root root   516 Aug 21 04:26 baselines_frozen.json
# -rw-r--r--  1 root root     0 Aug 21 04:19 .gitkeep
# -rw-r--r--  1 root root   592 Aug 21 04:20 mask_proof.json
# -rw-r--r--  1 root root 13677 Aug 21 05:42 qualitative.json
# -rw-r--r--  1 root root  1099 Aug 21 05:31 runs.csv
# -rw-r--r--  1 root root   277 Aug 21 04:20 template_check.json
# -rw-r--r--  1 root root   115 Aug 21 04:20 token_stats.json
# -rw-r--r--  1 root root   806 Aug 21 05:34 verdict.json
#
# ---- runs.csv ----
# run,label,tier,model,precision,placement,n_target_modules,r,lora_alpha,learning_rate,load_in_4bit,trainable_params,train_seconds,peak_vram_gb,final_loss,mask_mode,max_steps,teaches
# correct,all-linear · r=16 · LR 10x · 16-bit,T4,unsloth/Qwen3.5-4B,fp16,text-linear,12,16,32,0.0001,False,32464896,972.0,12.01,0.6266,assistant-only,30,
# attn_only,"q,v only · r=matched · LR 10x · 16-bit",T4,unsloth/Qwen3.5-4B,fp16,attn-only,2,283,566,0.0001,False,32456704,784.7,12.02,0.5372,,30,"Mistake #1 (§10.2): attention-only placement, rank raised to *match parameter count*. If rank were the lever, this would win."
# wrong_lr,all-linear · r=16 · LR 1x (full-FT scale) · 16-bit,T4,unsloth/Qwen3.5-4B,fp16,text-linear,12,16,32,1e-05,False,32464896,915.4,12.01,1.5704,,30,Mistake #2 (§10.3): a full-fine-tune learning rate applied to LoRA.
# qlora,all-linear · r=16 · LR 10x · 4-bit QLoRA,T4,unsloth/Qwen3.5-4B,fp16,text-linear,12,16,32,0.0001,True,32464896,974.9,7.09,0.7058,,30,The vendor says do NOT use QLoRA on Qwen3.5 (§12). Measure the cost yourself instead of taking either side on faith.
#
# ---- verdict.json ----
# {
#   "comparison": [
#     {
#       "run": "(a) base + naive prompt",
#       "target": 0.0,
#       "regression": 0.7578,
#       "format": 0.0,
#       "latency_ms": 3215.0,
#       "n": 50
#     },
#     {
#       "run": "(b) base + optimized prompt",
#       "target": 0.765,
#       "regression": 0.7578,
#       "format": 1.0,
#       "latency_ms": 1016.2,
#       "n": 50
#     },
#     {
#       "run": "(c) LoRA fine-tune",
#       "target": 0.97,
#       "regression": 0.6111,
#       "format": 1.0,
#       "latency_ms": 1382.9,
#       "n": 50
#     }
#   ],
#   "verdict": {
#     "passed": false,
#     "reasons": [
#       "general capability regressed by 0.147 (tolerance 0.020). See deck §14.3 — add 1-5% replay data."
#     ],
#     "target_delta": 0.20499999999999996,
#     "regression_delta": -0.14666666666666672
#   },
#   "valid_trace_rate": 0.0
# }
